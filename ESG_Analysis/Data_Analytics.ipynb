# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/MScBusinessAnalytics/Summative_Assessment/main/Data/Sample%201_CSV_S%26P1500_Raw%20Dataset_Data%20Analytics%20in%20Business%20Assignment_2021.csv')

df.head(10)
# Out:
#            Ticker                           Name  Year   ISIN Number  \
# 0  VRSK UW Equity           Verisk Analytics Inc  2016  US92345Y1064
# 1  EVTC UN Equity                    EVERTEC Inc  2016  PR30040P1032
# 2   PFG UW Equity  Principal Financial Group Inc  2016  US74251V1026
# 3  NXPI UW Equity          NXP Semiconductors NV  2016  NL0009538784
# 4  CELH UR Equity           Celsius Holdings Inc  2016  US15118V2079
# 5   AXP UN Equity            American Express Co  2016  US0258161092
# 6    VZ UN Equity     Verizon Communications Inc  2016  US92343V1044
# 7    BA UN Equity                  Boeing Co/The  2016  US0970231058
# 8   DOW UN Equity                        Dow Inc  2016  US2605571031
# 9  JYNT UR Equity                 Joint Corp/The  2016  US47973J1025
#
#    SIC Code  GICS Industry Country or Territory of Domicile  \
# 0    7374.0         202020                               US
# 1    7374.0         451020                               PR
# ...

# %%
df.shape
# Out:
# (4518, 20)

# %%
df['Environmental Disclosure Score'].isnull().sum()
# Out:
# 1339

# %%
df.dropna(subset=['Environmental Disclosure Score'], inplace=True)

df['Environmental Disclosure Score'].isnull().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Environmental Disclosure Score'].describe()
# Out:
# count    3179.000000
# mean       19.249815
# std        18.555317
# min         0.775200
# 25%         2.325600
# 50%        11.627900
# 75%        34.596750
# max        80.165300
# Name: Environmental Disclosure Score, dtype: float64

# %%
En_dis = df['Environmental Disclosure Score'].value_counts()
En_dis
# Out:
# 1.5504     490
# 1.7857     164
# 2.3256     104
# 3.8760     102
# 3.1008      77
#           ...
# 37.1901      1
# 64.4628      1
# 54.4828      1
# 34.4828      1
# 13.8211      1
# Name: Environmental Disclosure Score, Length: 295, dtype: int64

# %%
df['Return on Common Equity'].isnull().sum()
# Out:
# 108

# %%
df.dropna(subset=['Return on Common Equity'], inplace=True)
df['Return on Common Equity'].isnull().sum()
# Out:
# 0

# %%
df['Return on Common Equity'].describe()
# Out:
# count    3071.000000
# mean       16.774478
# std        44.832475
# min      -315.619100
# 25%         6.093750
# 50%        11.801800
# 75%        20.798350
# max      1048.621600
# Name: Return on Common Equity, dtype: float64

# %%
df['Return on Common Equity'].value_counts()
# Out:
# -315.6191    3
# -34.6570     3
# -61.0934     3
#  38.3138     3
#  56.8153     3
#             ..
#  12.5681     1
#  11.9557     1
#  6.5470      1
#  18.6418     1
#  12.2174     1
# Name: Return on Common Equity, Length: 3020, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.hist(df['Environmental Disclosure Score'], bins=50, color='r', edgecolor='b')
plt.title('Environmental Disclosure Score')
plt.xlabel('Scores')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
import matplotlib.pyplot as plt

plt.hist(df['Return on Common Equity'], bins=100, color='blue', edgecolor='black')
plt.title('Return on Common Euqity')
plt.xlabel('Return')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
df1 = df[['Environmental Disclosure Score', 'Return on Common Equity']].copy()

# %%
df1.head()
# Out:
#    Environmental Disclosure Score  Return on Common Equity
# 0                         22.4806                  43.7213
# 1                          4.6512                  73.9553
# 2                         25.8929                  13.4757
# 3                         40.3101                   1.7817
# 5                         48.2143                  25.5112

# %%
df1['Return on Common Equity'] = df1['Return on Common Equity'] / 100
df1.head()
# Out:
#    Environmental Disclosure Score  Return on Common Equity
# 0                         22.4806                 0.437213
# 1                          4.6512                 0.739553
# 2                         25.8929                 0.134757
# 3                         40.3101                 0.017817
# 5                         48.2143                 0.255112

# %%
import seaborn as sns

plt.ylim(-2, 2)
sns.regplot(x='Environmental Disclosure Score', y='Return on Common Equity', data=df1, fit_reg=True, color='.3',marker='*', line_kws=dict(color="r"))
# Out:
# <Axes: xlabel='Environmental Disclosure Score', ylabel='Return on Common Equity'>

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

X = df['Environmental Disclosure Score'].values.reshape(-1, 1)

y = df['Return on Common Equity'].values.reshape(-1, 1)

l_reg = linear_model.LinearRegression()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2)

model = l_reg.fit(X_train, y_train)
prediction = model.predict(X_test)
print('Prediction: ', prediction)
print('R^2 value: ', l_reg.score(X, y))
print('coedd: ', l_reg.coef_)
print('intercept', l_reg.intercept_)
# Out:
# Prediction:  [[23.98129947]
#  [11.78743388]
#  [14.44791001]
#  [22.20765825]
#  [23.98129947]
#  [25.97667801]
#  [14.89132746]
#  [14.00449255]
#  [17.77351231]
#  [12.11010131]
#  [11.85473015]
#  [24.36202529]
#  [13.11768625]
#  [12.45256007]
#  [13.33936637]
#  [11.78743388]
#  [25.97667801]
#  [17.77351231]
#  [14.22620128]
#  [17.77351231]
#  [30.41082395]
#  [11.78743388]
#  [11.78743388]
#  [11.85473015]
#  [20.21230831]
#  [11.78743388]
#  [26.86351292]
#  [11.85473015]
#  [22.42936698]
#  [12.00914261]
#  [15.55645364]
#  [11.78743388]
#  [19.76889086]
#  [12.00914261]
#  [11.78743388]
#  [28.19373668]
#  [11.78743388]
#  [11.85473015]
#  [11.93984433]
#  [19.99059958]
#  [11.78743388]
#  [23.31620189]
#  [25.97667801]
#  [11.85473015]
#  [14.40832734]
#  [11.78743388]
#  [12.67426879]
#  [21.54253207]
#  [11.78743388]
#  [13.33936637]
#  [14.44791001]
#  [13.78278383]
#  [11.85473015]
#  [22.0690903 ]
#  [12.45256007]
#  [28.8350389 ]
#  [15.17441221]
#  [11.78743388]
# ...

# %%
import statsmodels.api as sm

X = sm.add_constant(X)
model = sm.OLS(y, X)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     39.98
# Date:                Tue, 12 Dec 2023   Prob (F-statistic):           2.93e-10
# Time:                        18:51:13   Log-Likelihood:                -16016.
# No. Observations:                3071   AIC:                         3.204e+04
# Df Residuals:                    3069   BIC:                         3.205e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.4836      1.160      9.897      0.000       9.209      13.759
# ...

# %%
df['Return on Assets'].isnull().sum()
# Out:
# 0

# %%
df['Return on Assets'].value_counts()
# Out:
# 4.6659    3
# 3.2597    2
# 1.3067    2
# 3.1677    2
# 1.3557    2
#          ..
# 7.3474    1
# 8.7349    1
# 0.9186    1
# 8.4519    1
# 4.0383    1
# Name: Return on Assets, Length: 3032, dtype: int64

# %%
plt.hist(df['Return on Assets'], bins=100, color='yellow', edgecolor='black')
plt.title('Return on Assets')
plt.xlabel('Return')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
df2 = df[['Environmental Disclosure Score', 'Return on Assets']].copy()
df2['Return on Assets'] = df2['Return on Assets'] / 100
df2.head()
# Out:
#    Environmental Disclosure Score  Return on Assets
# 0                         22.4806          0.115639
# 1                          4.6512          0.085474
# 2                         25.8929          0.005895
# 3                         40.3101          0.007805
# 5                         48.2143          0.033586

# %%
import seaborn as sns

plt.ylim(-0.5, 0.5)
sns.regplot(x='Environmental Disclosure Score', y='Return on Assets', data=df2, fit_reg=True, color='.3',marker='+', line_kws=dict(color="b"))
# Out:
# <Axes: xlabel='Environmental Disclosure Score', ylabel='Return on Assets'>

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

X = df['Environmental Disclosure Score'].values.reshape(-1, 1)

y = df['Return on Assets'].values.reshape(-1, 1)

l_reg = linear_model.LinearRegression()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2)

model = l_reg.fit(X_train, y_train)
prediction = model.predict(X_test)
print('Prediction: ', prediction)
print('R^2 value: ', l_reg.score(X, y))
print('coedd: ', l_reg.coef_)
print('intercept', l_reg.intercept_)
# Out:
# Prediction:  [[6.04327344]
#  [4.86192309]
#  [7.31726846]
#  [6.67120452]
#  [4.43576322]
#  [4.33307385]
#  [5.25602007]
#  [5.68672803]
#  [4.60995613]
#  [5.65596289]
#  [5.80427213]
#  [4.51766468]
#  [5.31755034]
#  [4.34241214]
#  [6.27126169]
#  [5.18103203]
#  [4.59998683]
#  [5.22525493]
#  [4.33307385]
#  [4.34241214]
#  [4.33307385]
#  [5.50214117]
#  [4.33307385]
#  [6.32430298]
#  [5.31755034]
#  [4.76378182]
#  [6.02514059]
#  [4.76762746]
#  [5.80978859]
#  [5.80978859]
#  [4.51766468]
#  [5.72435897]
#  [4.62735478]
#  [5.96361428]
#  [5.62519776]
#  [4.33307385]
#  [4.94837265]
#  [4.34241214]
#  [6.7327348 ]
#  [5.00990293]
#  [4.33307385]
#  [5.00990293]
#  [4.57919099]
#  [4.93299008]
#  [4.70225154]
#  [5.19448979]
#  [4.33307385]
#  [4.64072127]
#  [4.64072127]
#  [5.65596289]
#  [5.68672803]
#  [6.1731998 ]
#  [6.13185815]
#  [5.47137603]
#  [6.64043938]
#  [5.71749317]
#  [4.48689955]
#  [4.54842585]
#  [6.51737883]
#  [5.50214117]
#  [5.37908062]
# ...

# %%
X = sm.add_constant(X)
model = sm.OLS(y, X)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     25.77
# Date:                Tue, 12 Dec 2023   Prob (F-statistic):           4.08e-07
# Time:                        18:51:16   Log-Likelihood:                -10589.
# No. Observations:                3071   AIC:                         2.118e+04
# Df Residuals:                    3069   BIC:                         2.119e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.3127      0.198     21.758      0.000       3.924       4.701
# ...

# %%
df.head()
# Out:
#            Ticker                           Name  Year   ISIN Number  \
# 0  VRSK UW Equity           Verisk Analytics Inc  2016  US92345Y1064
# 1  EVTC UN Equity                    EVERTEC Inc  2016  PR30040P1032
# 2   PFG UW Equity  Principal Financial Group Inc  2016  US74251V1026
# 3  NXPI UW Equity          NXP Semiconductors NV  2016  NL0009538784
# 5   AXP UN Equity            American Express Co  2016  US0258161092
#
#    SIC Code  GICS Industry Country or Territory of Domicile  \
# 0    7374.0         202020                               US
# 1    7374.0         451020                               PR
# 2    6321.0         403010                               US
# 3    3674.0         453010                               NL
# 5    6199.0         402020                               US
#
#    Number of Employees  Total Assets  R&D Expense  R&D Expense Adjusted  \
# 0               6148.0      4631.200         27.4                  27.4
# ...

# %%
df['Gross Margin'].isnull().sum()
# Out:
# 735

# %%
df.dropna(subset=['Gross Margin'], inplace=True)
df['Gross Margin'].isnull().sum()
# Out:
# 0

# %%
plt.hist(df['Gross Margin'], bins=100, color='gray', edgecolor='black')
plt.title('Gross Margin')
plt.xlabel('Gross Margin')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
df3 = df[['Environmental Disclosure Score', 'Gross Margin']].copy()
df3['Gross Margin'] = df3['Gross Margin'] / 100
df3.head()
# Out:
#    Environmental Disclosure Score  Gross Margin
# 0                         22.4806      0.641941
# 1                          4.6512      0.548637
# 3                         40.3101      0.428406
# 6                         29.2683      0.581672
# 7                         28.6822      0.154766

# %%
import seaborn as sns

sns.regplot(x='Environmental Disclosure Score', y='Gross Margin', data=df3, fit_reg=True, color='.3',marker='o', line_kws=dict(color="g"))
# Out:
# <Axes: xlabel='Environmental Disclosure Score', ylabel='Gross Margin'>

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

X = df['Environmental Disclosure Score'].values.reshape(-1, 1)

y = df['Gross Margin'].values.reshape(-1, 1)

l_reg = linear_model.LinearRegression()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2)

model = l_reg.fit(X_train, y_train)
prediction = model.predict(X_test)
print('Prediction: ', prediction)
print('R^2 value: ', l_reg.score(X, y))
print('coedd: ', l_reg.coef_)
print('intercept', l_reg.intercept_)
# Out:
# Prediction:  [[38.73960532]
#  [40.55427805]
#  [37.15908585]
#  [37.10054754]
#  [37.15908585]
#  [37.51030821]
#  [37.10054754]
#  [37.10054754]
#  [37.39323912]
#  [37.74446147]
#  [37.15908585]
#  [37.27616249]
#  [37.10054754]
#  [37.21762417]
#  [41.38844151]
#  [37.86153811]
#  [37.92007643]
#  [37.80299979]
#  [38.27130633]
#  [37.27616249]
#  [37.33470081]
#  [39.79328747]
#  [40.26159401]
#  [37.39323912]
#  [38.21276801]
#  [38.79814363]
#  [38.15422969]
#  [38.44691373]
#  [37.21762417]
#  [37.80299979]
#  [42.54456573]
#  [37.86153811]
#  [39.95194202]
#  [37.92007643]
#  [38.32069237]
#  [37.68592316]
#  [39.14937354]
#  [39.91036411]
#  [37.10054754]
#  [40.14451738]
#  [37.21762417]
#  [37.45177744]
#  [38.32984465]
#  [39.20791185]
#  [40.14451738]
#  [38.39935512]
#  [37.10054754]
#  [37.21945161]
#  [37.45177744]
#  [39.50059589]
#  [41.2567303 ]
#  [37.21762417]
#  [40.96404627]
#  [40.32012478]
#  [37.10054754]
#  [41.6079602 ]
#  [38.09569138]
#  [40.08597906]
# ...

# %%
X = sm.add_constant(X)
model = sm.OLS(y, X)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     13.77
# Date:                Tue, 12 Dec 2023   Prob (F-statistic):           0.000211
# Time:                        18:51:18   Log-Likelihood:                -10363.
# No. Observations:                2336   AIC:                         2.073e+04
# Df Residuals:                    2334   BIC:                         2.074e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         36.6535      0.627     58.420      0.000      35.423      37.884
# ...

# %%
df['Social Disclosure Score'].isnull().sum()
# Out:
# 0

# %%
plt.hist(df['Social Disclosure Score'], bins=30, color='yellow', edgecolor='b')
plt.title('Social Disclosure Score')
plt.xlabel('Scores')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
df_S = df[['Social Disclosure Score', 'Return on Common Equity', 'Return on Assets', 'Gross Margin']].copy()
df_S['Return on Assets'] = df_S['Return on Assets'] / 100
df_S['Return on Common Equity'] = df_S['Return on Common Equity'] / 100
df_S['Gross Margin'] = df_S['Gross Margin'] / 100
df_S.head()
# Out:
#    Social Disclosure Score  Return on Common Equity  Return on Assets  \
# 0                  38.5965                 0.437213          0.115639
# 1                  24.5614                 0.739553          0.085474
# 3                  28.0702                 0.017817          0.007805
# 6                  46.8750                 0.674009          0.053760
# 7                  24.5614                 1.407718          0.054597
#
#    Gross Margin
# 0      0.641941
# 1      0.548637
# 3      0.428406
# 6      0.581672
# 7      0.154766

# %%
sns.regplot(x='Social Disclosure Score', y='Return on Common Equity', data=df_S, fit_reg=True, color='.3',marker='o', line_kws=dict(color="yellow"))
# Out:
# <Axes: xlabel='Social Disclosure Score', ylabel='Return on Common Equity'>

# %%
sns.regplot(x='Social Disclosure Score', y='Return on Assets', data=df_S, fit_reg=True, color='.3',marker='o', line_kws=dict(color="orange"))
# Out:
# <Axes: xlabel='Social Disclosure Score', ylabel='Return on Assets'>

# %%
sns.regplot(x='Social Disclosure Score', y='Gross Margin', data=df_S, fit_reg=True, color='.3',marker='o', line_kws=dict(color="purple"))
# Out:
# <Axes: xlabel='Social Disclosure Score', ylabel='Gross Margin'>

# %%
X = df['Social Disclosure Score'].values.reshape(-1, 1)

y_ROE = df['Return on Common Equity'].values.reshape(-1, 1)

X = sm.add_constant(X)
model = sm.OLS(y_ROE, X)
result = model.fit()
print('Social_Score & ROE', result.summary())

y_ROA = df['Return on Assets'].values.reshape(-1, 1)
model = sm.OLS(y_ROA, X)
result = model.fit()
print('Social_Score & ROA', result.summary())

y_GM = df['Gross Margin'].values.reshape(-1, 1)
model = sm.OLS(y_GM, X)
result = model.fit()
print('Social_Score & GM', result.summary())
# Out:
# Social_Score & ROE                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     26.97
# Date:                Tue, 12 Dec 2023   Prob (F-statistic):           2.25e-07
# Time:                        18:51:25   Log-Likelihood:                -12461.
# No. Observations:                2336   AIC:                         2.493e+04
# Df Residuals:                    2334   BIC:                         2.494e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.4796      2.192      3.869      0.000       4.181      12.778
# ...

# %%
df['Governance Disclosure Score'].isnull().sum()
# Out:
# 0

# %%
plt.hist(df['Governance Disclosure Score'], bins=30, color='yellow', edgecolor='b')
plt.title('Governance Disclosure Score')
plt.xlabel('Scores')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
df_G = df[['Governance Disclosure Score', 'Return on Common Equity', 'Return on Assets', 'Gross Margin']].copy()
df_G['Return on Assets'] = df_G['Return on Assets'] / 100
df_G['Return on Common Equity'] = df_G['Return on Common Equity'] / 100
df_G['Gross Margin'] = df_G['Gross Margin'] / 100
df_G.head()
# Out:
#    Governance Disclosure Score  Return on Common Equity  Return on Assets  \
# 0                      60.7143                 0.437213          0.115639
# 1                      51.7857                 0.739553          0.085474
# 3                      26.7857                 0.017817          0.007805
# 6                      80.3571                 0.674009          0.053760
# 7                      55.3571                 1.407718          0.054597
#
#    Gross Margin
# 0      0.641941
# 1      0.548637
# 3      0.428406
# 6      0.581672
# 7      0.154766

# %%
sns.regplot(x='Governance Disclosure Score', y='Return on Common Equity', data=df_G, fit_reg=True, color='.3',marker='o', line_kws=dict(color="yellow"))
# Out:
# <Axes: xlabel='Governance Disclosure Score', ylabel='Return on Common Equity'>

# %%
sns.regplot(x='Governance Disclosure Score', y='Return on Assets', data=df_G, fit_reg=True, color='.3',marker='o', line_kws=dict(color="orange"))
# Out:
# <Axes: xlabel='Governance Disclosure Score', ylabel='Return on Assets'>

# %%
sns.regplot(x='Governance Disclosure Score', y='Gross Margin', data=df_G, fit_reg=True, color='.3',marker='o', line_kws=dict(color="purple"))
# Out:
# <Axes: xlabel='Governance Disclosure Score', ylabel='Gross Margin'>

# %%
X = df['Governance Disclosure Score'].values.reshape(-1, 1)

y_ROE = df['Return on Common Equity'].values.reshape(-1, 1)

X = sm.add_constant(X)
model = sm.OLS(y_ROE, X)
result = model.fit()
print('Governance_Score & ROE', result.summary())

y_ROA = df['Return on Assets'].values.reshape(-1, 1)
model = sm.OLS(y_ROA, X)
result = model.fit()
print('Governance_Score & ROA', result.summary())

y_GM = df['Gross Margin'].values.reshape(-1, 1)
model = sm.OLS(y_GM, X)
result = model.fit()
print('Governance_Score & GM', result.summary())
# Out:
# Governance_Score & ROE                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     24.33
# Date:                Tue, 12 Dec 2023   Prob (F-statistic):           8.67e-07
# Time:                        18:51:29   Log-Likelihood:                -12462.
# No. Observations:                2336   AIC:                         2.493e+04
# Df Residuals:                    2334   BIC:                         2.494e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -23.0556      8.489     -2.716      0.007     -39.702      -6.409
# ...

# %%
import numpy as np

EDS = np.linspace(0, 100, 100)

ROE_pred = 0.29 * EDS + 11.39

ROE_pred
# Out:
# array([11.39      , 11.68292929, 11.97585859, 12.26878788, 12.56171717,
#        12.85464646, 13.14757576, 13.44050505, 13.73343434, 14.02636364,
#        14.31929293, 14.61222222, 14.90515152, 15.19808081, 15.4910101 ,
#        15.78393939, 16.07686869, 16.36979798, 16.66272727, 16.95565657,
#        17.24858586, 17.54151515, 17.83444444, 18.12737374, 18.42030303,
#        18.71323232, 19.00616162, 19.29909091, 19.5920202 , 19.88494949,
#        20.17787879, 20.47080808, 20.76373737, 21.05666667, 21.34959596,
#        21.64252525, 21.93545455, 22.22838384, 22.52131313, 22.81424242,
#        23.10717172, 23.40010101, 23.6930303 , 23.9859596 , 24.27888889,
#        24.57181818, 24.86474747, 25.15767677, 25.45060606, 25.74353535,
#        26.03646465, 26.32939394, 26.62232323, 26.91525253, 27.20818182,
#        27.50111111, 27.7940404 , 28.0869697 , 28.37989899, 28.67282828,
#        28.96575758, 29.25868687, 29.55161616, 29.84454545, 30.13747475,
# ...

# %%
print(f"Max: {ROE_pred.max()}")
print(f"Min: {ROE_pred.min()}")
print(f"Mean: {ROE_pred.mean()}")
# Out:
# Max: 40.39
# Min: 11.39
# Mean: 25.89

# %%
plt.plot(EDS, ROE_pred)
plt.xlabel('Environmental Disclosure Score')
plt.ylabel('Return on Common Equity')
plt.title('Relationship between EDS & ROE')
# Out:
# Text(0.5, 1.0, 'Relationship between EDS & ROE')
